# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/yolo_model_training
# Out:
# /content/drive/My Drive/yolo_model_training

# %%
ls '/content/drive/My Drive/yolo_model_training'
# Out:
# All_Custom_Object/
# All_Custom_Object.zip
# backup/
# Celeb_Faces/
# Celeb_Faces.zip
# creating-files-data-and-name.py
# creating-train-and-test-txt-files.py
# Custom_Object/
# Custom_Objects.zip
# darknet/
# eye_gender_data/
# faces_weight/
# training_yolo_custom_object_detection_files-main/

# %%
# !unzip '/content/drive/My Drive/yolo_model_training/Celeb_Faces.zip' -d '/content/drive/My Drive/yolo_model_training/Celeb_Faces'
# Out:
# Archive:  /content/drive/My Drive/yolo_model_training/Celeb_Faces.zip
#    creating: /content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/
#   inflating: /content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/ariana_1.jpg
#   inflating: /content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/ariana_1.txt
#   inflating: /content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/ariana_10.jpg
#   inflating: /content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/ariana_10.txt
#   inflating: /content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/ariana_100.jpg
#   inflating: /content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/ariana_100.txt
#   inflating: /content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/ariana_11.jpg
#   inflating: /content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/ariana_11.txt
# ...

# %%
# !git clone https://github.com/AlexeyAB/darknet/
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %%
cd darknet
# Out:
# /content/drive/My Drive/yolo_model_training/darknet

# %%
# !make
# Out:
# chmod +x *.sh

# %%
# !chmod +x darknet

# %%
cd '/content/drive/My Drive/yolo_model_training'
# Out:
# /content/drive/My Drive/yolo_model_training

# %%
ls '/content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces'
# Out:
# ariana_100.jpg  ariana_49.jpg   justin_12.txt  justin_54.jpg
# ariana_100.txt  ariana_49.txt   justin_13.jpg  justin_54.txt
# ariana_10.jpg   ariana_4.jpg    justin_13.txt  justin_55.jpg
# ariana_10.txt   ariana_4.txt    justin_14.jpg  justin_55.txt
# ariana_11.jpg   ariana_50.jpg   justin_14.txt  justin_56.jpg
# ariana_11.txt   ariana_50.txt   justin_15.jpg  justin_56.txt
# ariana_12.jpg   ariana_51.jpg   justin_15.txt  justin_57.jpg
# ariana_12.txt   ariana_51.txt   justin_16.jpg  justin_57.txt
# ariana_13.jpg   ariana_53.jpg   justin_16.txt  justin_58.jpg
# ariana_13.txt   ariana_53.txt   justin_17.jpg  justin_58.txt
# ariana_14.jpg   ariana_56.jpg   justin_17.txt  justin_59.jpg
# ariana_14.txt   ariana_56.txt   justin_18.jpg  justin_59.txt
# ariana_15.jpg   ariana_57.jpg   justin_18.txt  justin_5.jpg
# ariana_15.txt   ariana_57.txt   justin_19.jpg  justin_5.txt
# ariana_16.jpg   ariana_58.jpg   justin_19.txt  justin_60.jpg
# ...

# %%
# !python creating-files-data-and-name.py

# %%
# !python creating-train-and-test-txt-files.py
# Out:
# ['/content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/justin_4.jpg\n', '/content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/justin_18.jpg\n', '/content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/justin_28.jpg\n', '/content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/justin_40.jpg\n', '/content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/justin_48.jpg\n', '/content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/justin_66.jpg\n', '/content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/justin_73.jpg\n', '/content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/justin_78.jpg\n', '/content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/justin_83.jpg\n', '/content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/justin_97.jpg\n', '/content/drive/My Drive/yolo_model_training/Celeb_Faces/Celeb_Faces/ariana_15.jpg\n', '/content/drive/My Drive/yolo_model_train
# ...

# %%
cd /content/drive/MyDrive/yolo_model_training/darknet
# Out:
# /content/drive/MyDrive/yolo_model_training/darknet

# %%
# !chmod +x darknet

# %%
# !./darknet detector train data/labelled_data_faces.data cfg/yolov3_custom.cfg darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 43014, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 0.000104, iou_loss = 0.000000, total_loss = 0.000104
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.734939), count: 1, class_loss = 0.911034, iou_loss = 0.442631, total_loss = 1.353665
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000010, iou_loss = 0.000000, total_loss = 0.000010
#  total_bbox = 43015, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.786101), count: 1, class_loss = 0.579988, iou_loss = 0.094378, total_loss = 0.674366
# ...

# %%
# !./darknet detector test data/labelled_data_faces.data cfg/yolov3_custom.cfg backup/yolov3_custom_last.weights -dont_show /content/drive/MyDrive/yolo_model_training/Celeb_Faces/Celeb_Faces/justin_4.jpg
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...
